# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('telecom_churn.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
len(df)
# Out:
# 3333

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
# 각 feature에 대한 통계치를 출력하는 함수
pd.set_option('display.precision', 2)
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
# dexcribe는 수치를 이용한 함수로 수치가 아닌 값은 포함되지 않음
# 때문에 columns이 20개가 아닌 16개만 출력
a = df.describe()
a.shape
# Out:
# (8, 16)

# %%
# default int64 (int -> int64)
df['Churn'] = df['Churn'].astype('int')
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe(include=['float64'])
# Out:
#        Total day minutes  Total day charge  Total eve minutes  \
# count            3333.00           3333.00            3333.00
# mean              179.78             30.56             200.98
# std                54.47              9.26              50.71
# min                 0.00              0.00               0.00
# 25%               143.70             24.43             166.60
# 50%               179.40             30.50             201.40
# 75%               216.40             36.79             235.30
# max               350.80             59.64             363.70
#
#        Total eve charge  Total night minutes  Total night charge  \
# count           3333.00              3333.00             3333.00
# mean              17.08               200.87                9.04
# std                4.31                50.57                2.28
# min                0.00                23.20                1.04
# 25%               14.16               167.00                7.52
# ...

# %%
# 비율을 보는 한 방법
df['Area code'].value_counts(normalize=True)
# Out:
# 415    0.50
# 510    0.25
# 408    0.25
# Name: Area code, dtype: float64

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
# Churn이 1인 항목의 평균
df[df['Churn'] == 1].mean()
# Out:
# Account length            102.66
# Area code                 437.82
# Number vmail messages       5.12
# Total day minutes         206.91
# Total day calls           101.34
# Total day charge           35.18
# Total eve minutes         212.41
# Total eve calls           100.56
# Total eve charge           18.05
# Total night minutes       205.23
# Total night calls         100.40
# Total night charge          9.24
# Total intl minutes         10.70
# Total intl calls            4.16
# Total intl charge           2.89
# Customer service calls      2.23
# Churn                       1.00
# dtype: float64

# %%
# 요런식으로 각 항목을 접근할 수도 있음
df[df['Churn'] == 1]['Total day minutes']
# Out:
# 10      129.1
# 15      332.9
# 21       62.4
# 33      249.6
# 41      173.1
#         ...
# 3301    280.0
# 3304    186.1
# 3320    140.0
# 3322    321.1
# 3323    118.4
# Name: Total day minutes, Length: 483, dtype: float64

# %%
a = df['Churn'] == 0
a
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3328    True
# 3329    True
# 3330    True
# 3331    True
# 3332    True
# Name: Churn, Length: 3333, dtype: bool

# %%
a = df['International plan'] == 'No'
a
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 3328     True
# 3329     True
# 3330     True
# 3331    False
# 3332     True
# Name: International plan, Length: 3333, dtype: bool

# %%
df['Churn'] = df['Churn'].astype('bool')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
# AND or OR 연산 사용시 소괄호는 필수!!, 하지 않을 시 에러 발생
df[(df['Churn'] is False) & (df['International plan'] == 'No')]['Total intl minutes']
df[(df['Churn'] == False) & (df['International plan'] == 'No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
df.loc[:5, "State":"Area code"]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[:6, :3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
# DataFrame의 마지막 행을 가지고 오는 다양한 방버
#df.iloc[len(df)-1]
#df.iloc[-1]
df[-1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3332             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3332                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3332                       0  False

# %%
# It's my solution .. using pandas method
# df.max()
# using numpy method
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                      True
# dtype: object

# %%
# WoW!! pandas pactice solution ..!!
df['State'].apply(lambda state:state[0] == 'W')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329     True
# 3330    False
# 3331    False
# 3332    False
# Name: State, Length: 3333, dtype: bool

# %%
d1 = {'Yes':True, 'No':False}

def d2(x):
    if x=='Yes':
        return True
    else :
        return False

df['International plan'].apply(d2)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331     True
# 3332    False
# Name: International plan, Length: 3333, dtype: bool

# %%
# 딕셔너리를 이용하여 DataFrame 내부 값을 변경하는 방법들
#df['Voice mail plan'] = df['Voice mail plan'].map(d1)
df = pd.read_csv('telecom_churn.csv')
df.replace({'Voice mail plan' : d1})
# Out:
#      State  Account length  Area code International plan  Voice mail plan  \
# 0       KS             128        415                 No             True
# 1       OH             107        415                 No             True
# 2       NJ             137        415                 No            False
# 3       OH              84        408                Yes            False
# 4       OK              75        415                Yes            False
# ...    ...             ...        ...                ...              ...
# 3328    AZ             192        415                 No             True
# 3329    WV              68        415                 No            False
# 3330    RI              28        510                 No            False
# 3331    CT             184        510                Yes            False
# 3332    TN              74        415                 No             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.groupby('Churn').mean().loc[:, ["Total day minutes", "Total eve minutes", "Total night minutes"]]
# Out:
#        Total day minutes  Total eve minutes  Total night minutes
# Churn
# False             175.18             199.04               200.13
# True              206.91             212.41               205.23

# %%
# crosstab 두 데이터 프레임을 조합하여 해당하는 수를 표현하는 메서드
pd.set_option('display.precision', 2)
pd.crosstab(df['Churn'], df['International plan'], normalize=True)
# Out:
# International plan   No   Yes
# Churn
# False               0.8  0.06
# True                0.1  0.04

# %%
df.groupby('Area code').mean().loc[:, ["Total day minutes", "Total eve minutes", "Total night minutes"]]
# Out:
#            Total day minutes  Total eve minutes  Total night minutes
# Area code
# 408                   177.18             201.28               199.21
# 415                   181.59             200.65               202.04
# 510                   178.79             201.32               200.23

# %%
# 위와 같은 출력인데 pivot table을 이용하는 방법
# 조교가 푼 방식인데 재밋네
df.pivot_table(["Total day minutes", "Total eve minutes", "Total night minutes"], ['Area code'], aggfunc='mean')
# Out:
#            Total day minutes  Total eve minutes  Total night minutes
# Area code
# 408                   177.18             201.28               199.21
# 415                   181.59             200.65               202.04
# 510                   178.79             201.32               200.23

# %%
df['Total minutes'] = df['Total day minutes'] + df['Total night minutes'] + df['Total eve minutes']
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 요기까진 삽입 안된거지..
total = df['Total day minutes'] + df['Total night minutes'] + df['Total eve minutes']
type(total)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.insert(loc=len(df.columns), column="Total minutes-2", value=total)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df = df.drop(10)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df = df.drop(['Voice mail plan'], axis = 1)
df
# Out:
#      State  Account length  Area code International plan  \
# 1       OH             107        415                 No
# 2       NJ             137        415                 No
# 3       OH              84        408                Yes
# 4       OK              75        415                Yes
# 5       AL             118        510                Yes
# ...    ...             ...        ...                ...
# 3328    AZ             192        415                 No
# 3329    WV              68        415                 No
# 3330    RI              28        510                 No
# 3331    CT             184        510                Yes
# 3332    TN              74        415                 No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# ...
